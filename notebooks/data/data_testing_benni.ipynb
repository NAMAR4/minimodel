# %% [markdown]
# ### This Notebook is used to inspect the data and understand what kind of data is stored in hte files

# %%
import numpy as np

# %%
data = np.load("monkeyv1_cadena_2019.npz")
print(data.files)   # Liste aller Keys
# Out:
# ['images', 'responses', 'real_responses', 'test_images', 'test_responses', 'test_real_responses', 'train_idx', 'val_idx', 'subject_id', 'repetitions', 'image_ids']
