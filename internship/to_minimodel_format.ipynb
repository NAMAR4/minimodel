# %% [markdown]
# ### This notbook takes in the data in the experanto format and translates the data into the minimodel format
#
# I will see if I am gone write this exporter. There are a few problems.
# 1. I have split up the data of the images and the mice into multiple experiments. Not all mice use all images. To merge together all the images could be hard.
